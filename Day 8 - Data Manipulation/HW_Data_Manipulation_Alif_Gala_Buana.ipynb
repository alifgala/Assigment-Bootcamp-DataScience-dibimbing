# %%
# --- Data Manipulation ----
import pandas as pd
pd.set_option("display.max_columns",None) #menampilkan semua coloumn biar gak titiktitik

#--- Numerical Computation ----
import numpy as np

# %%
df = pd.read_csv("telco_customer_churn.csv")

# %%
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity OnlineBackup  \
# 0  No phone service             DSL             No          Yes
# 1                No             DSL            Yes           No
# 2                No             DSL            Yes          Yes
# 3  No phone service             DSL            Yes           No
# 4                No     Fiber optic             No           No
#
#   DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# 0               No          No          No              No  Month-to-month
# 1              Yes          No          No              No        One year
# 2               No          No          No              No  Month-to-month
# 3              Yes         Yes          No              No        One year
# 4               No          No          No              No  Month-to-month
#
#   PaperlessBilling              PaymentMethod  MonthlyCharges TotalCharges  \
# 0              Yes           Electronic check           29.85        29.85
# 1               No               Mailed check           56.95       1889.5
# 2              Yes               Mailed check           53.85       108.15
# 3               No  Bank transfer (automatic)           42.30      1840.75
# 4              Yes           Electronic check           70.70       151.65
#
#   Churn
# 0    No
# 1    No
# 2   Yes
# 3    No
# 4   Yes

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
#  16  PaperlessBilling  7043 non-null   object
#  17  PaymentMethod     7043 non-null   object
#  18  MonthlyCharges    7043 non-null   float64
#  19  TotalCharges      7043 non-null   object
#  20  Churn             7043 non-null   object
# dtypes: float64(1), int64(2), object(18)
# memory usage: 1.1+ MB

# %%
df
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 1     5575-GNVDE    Male              0      No         No      34
# 2     3668-QPYBK    Male              0      No         No       2
# 3     7795-CFOCW    Male              0      No         No      45
# 4     9237-HQITU  Female              0      No         No       2
# ...          ...     ...            ...     ...        ...     ...
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  \
# 0              No  No phone service             DSL             No
# 1             Yes                No             DSL            Yes
# 2             Yes                No             DSL            Yes
# 3              No  No phone service             DSL            Yes
# 4             Yes                No     Fiber optic             No
# ...           ...               ...             ...            ...
# 7038          Yes               Yes             DSL            Yes
# 7039          Yes               Yes     Fiber optic             No
# 7040           No  No phone service             DSL            Yes
# 7041          Yes               Yes     Fiber optic             No
# 7042          Yes                No     Fiber optic            Yes
#
#      OnlineBackup DeviceProtection TechSupport StreamingTV StreamingMovies  \
# 0             Yes               No          No          No              No
# 1              No              Yes          No          No              No
# 2             Yes               No          No          No              No
# 3              No              Yes         Yes          No              No
# 4              No               No          No          No              No
# ...           ...              ...         ...         ...             ...
# 7038           No              Yes         Yes         Yes             Yes
# 7039          Yes              Yes          No         Yes             Yes
# 7040           No               No          No          No              No
# 7041           No               No          No          No              No
# 7042           No              Yes         Yes         Yes             Yes
#
#             Contract PaperlessBilling              PaymentMethod  \
# 0     Month-to-month              Yes           Electronic check
# 1           One year               No               Mailed check
# 2     Month-to-month              Yes               Mailed check
# 3           One year               No  Bank transfer (automatic)
# 4     Month-to-month              Yes           Electronic check
# ...              ...              ...                        ...
# 7038        One year              Yes               Mailed check
# 7039        One year              Yes    Credit card (automatic)
# 7040  Month-to-month              Yes           Electronic check
# 7041  Month-to-month              Yes               Mailed check
# 7042        Two year              Yes  Bank transfer (automatic)
#
#       MonthlyCharges TotalCharges Churn
# 0              29.85        29.85    No
# 1              56.95       1889.5    No
# 2              53.85       108.15   Yes
# 3              42.30      1840.75    No
# 4              70.70       151.65   Yes
# ...              ...          ...   ...
# 7038           84.80       1990.5    No
# 7039          103.20       7362.9    No
# 7040           29.60       346.45    No
# 7041           74.40        306.6   Yes
# 7042          105.65       6844.5    No
#
# [7043 rows x 21 columns]

# %% [markdown]
# ## Soal 1
# Buat fungsi Python untuk memfilter churn untuk menemukan pelanggan yang berisiko tinggi.
# Pelanggan berisiko tinggi didefinisikan sebagai pelanggan yang memiliki kontrak bulanan
# dan tagihan bulanan yang tinggi (di atas persentil 90%).

# %%
## data pelanggan dengan kontrak bulanan
pelanggan_highrisk = df[df["Contract"] == "Month-to-month"]
pelanggan_highrisk
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 2     3668-QPYBK    Male              0      No         No       2
# 4     9237-HQITU  Female              0      No         No       2
# 5     9305-CDSKC  Female              0      No         No       8
# 6     1452-KIOVK    Male              0      No        Yes      22
# ...          ...     ...            ...     ...        ...     ...
# 7033  9767-FFLEM    Male              0      No         No      38
# 7034  0639-TSIQW  Female              0      No         No      67
# 7035  8456-QDAVC    Male              0      No         No      19
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  \
# 0              No  No phone service             DSL             No
# 2             Yes                No             DSL            Yes
# 4             Yes                No     Fiber optic             No
# 5             Yes               Yes     Fiber optic             No
# 6             Yes               Yes     Fiber optic             No
# ...           ...               ...             ...            ...
# 7033          Yes                No     Fiber optic             No
# 7034          Yes               Yes     Fiber optic            Yes
# 7035          Yes                No     Fiber optic             No
# 7040           No  No phone service             DSL            Yes
# 7041          Yes               Yes     Fiber optic             No
#
#      OnlineBackup DeviceProtection TechSupport StreamingTV StreamingMovies  \
# 0             Yes               No          No          No              No
# 2             Yes               No          No          No              No
# 4              No               No          No          No              No
# 5              No              Yes          No         Yes             Yes
# 6             Yes               No          No         Yes              No
# ...           ...              ...         ...         ...             ...
# 7033           No               No          No          No              No
# 7034          Yes              Yes          No         Yes              No
# 7035           No               No          No         Yes              No
# 7040           No               No          No          No              No
# 7041           No               No          No          No              No
#
#             Contract PaperlessBilling              PaymentMethod  \
# 0     Month-to-month              Yes           Electronic check
# 2     Month-to-month              Yes               Mailed check
# 4     Month-to-month              Yes           Electronic check
# 5     Month-to-month              Yes           Electronic check
# 6     Month-to-month              Yes    Credit card (automatic)
# ...              ...              ...                        ...
# 7033  Month-to-month              Yes    Credit card (automatic)
# 7034  Month-to-month              Yes    Credit card (automatic)
# 7035  Month-to-month              Yes  Bank transfer (automatic)
# 7040  Month-to-month              Yes           Electronic check
# 7041  Month-to-month              Yes               Mailed check
#
#       MonthlyCharges TotalCharges Churn
# 0              29.85        29.85    No
# 2              53.85       108.15   Yes
# 4              70.70       151.65   Yes
# 5              99.65        820.5   Yes
# 6              89.10       1949.4    No
# ...              ...          ...   ...
# 7033           69.50      2625.25    No
# 7034          102.95      6886.25   Yes
# 7035           78.70       1495.1    No
# 7040           29.60       346.45    No
# 7041           74.40        306.6   Yes
#
# [3875 rows x 21 columns]

# %%
p_90 = np.percentile(df['MonthlyCharges'], 90)
p_90
# Out:
# 102.6

# %%
#memfilter pelanggan dengan kontrak bulanan dan tagihan bulanan tinggi (percentile 90%)
pelanggan_highrisk = df[(df["Contract"] == "Month-to-month") & (df["MonthlyCharges"] >= p_90)]
pelanggan_highrisk
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 8     7892-POOKP  Female              0     Yes         No      28
# 13    0280-XJGEX    Male              0      No         No      49
# 14    5129-JLPIS    Male              0      No         No      25
# 38    5380-WJKOV    Male              0      No         No      34
# 83    9919-YLNNG  Female              0      No         No      42
# ...          ...     ...            ...     ...        ...     ...
# 6952  6394-MFYNG  Female              0      No         No      48
# 6963  9547-ITEFG    Male              0     Yes        Yes       9
# 7006  0093-XWZFY    Male              0      No         No      40
# 7023  1035-IPQPU  Female              1     Yes         No      63
# 7034  0639-TSIQW  Female              0      No         No      67
#
#      PhoneService MultipleLines InternetService OnlineSecurity OnlineBackup  \
# 8             Yes           Yes     Fiber optic             No           No
# 13            Yes           Yes     Fiber optic             No          Yes
# 14            Yes            No     Fiber optic            Yes           No
# 38            Yes           Yes     Fiber optic             No          Yes
# 83            Yes            No     Fiber optic             No          Yes
# ...           ...           ...             ...            ...          ...
# 6952          Yes           Yes     Fiber optic             No          Yes
# 6963          Yes           Yes     Fiber optic             No          Yes
# 7006          Yes           Yes     Fiber optic             No          Yes
# 7023          Yes           Yes     Fiber optic             No          Yes
# 7034          Yes           Yes     Fiber optic            Yes          Yes
#
#      DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# 8                 Yes         Yes         Yes             Yes  Month-to-month
# 13                Yes          No         Yes             Yes  Month-to-month
# 14                Yes         Yes         Yes             Yes  Month-to-month
# 38                Yes          No         Yes             Yes  Month-to-month
# 83                Yes         Yes         Yes             Yes  Month-to-month
# ...               ...         ...         ...             ...             ...
# 6952              Yes          No         Yes             Yes  Month-to-month
# 6963              Yes          No         Yes             Yes  Month-to-month
# 7006              Yes          No         Yes             Yes  Month-to-month
# 7023              Yes          No         Yes             Yes  Month-to-month
# 7034              Yes          No         Yes              No  Month-to-month
#
#      PaperlessBilling              PaymentMethod  MonthlyCharges TotalCharges  \
# 8                 Yes           Electronic check          104.80      3046.05
# 13                Yes  Bank transfer (automatic)          103.70       5036.3
# 14                Yes           Electronic check          105.50      2686.05
# 38                Yes           Electronic check          106.35      3549.25
# 83                Yes  Bank transfer (automatic)          103.80       4327.5
# ...               ...                        ...             ...          ...
# 6952              Yes  Bank transfer (automatic)          107.40       5121.3
# 6963              Yes    Credit card (automatic)          102.60       897.75
# 7006              Yes    Credit card (automatic)          104.50      4036.85
# 7023              Yes           Electronic check          103.50       6479.4
# 7034              Yes    Credit card (automatic)          102.95      6886.25
#
#      Churn
# 8      Yes
# 13     Yes
# 14      No
# 38     Yes
# 83      No
# ...    ...
# 6952   Yes
# 6963    No
# 7006   Yes
# 7023    No
# 7034   Yes
#
# [209 rows x 21 columns]

# %% [markdown]
# ## Soal 2
# Buat script Python untuk mengelompokkan data berdasarkan jenis kontrak dan menghitung
# rata-rata tagihan bulanan serta persentase churn untuk setiap grup (1 dan 0, rata rata untuk
# menghitung persentase)

# %%
group_1 = df.groupby(["Contract","Churn"]).agg({"MonthlyCharges" : "mean"})
group_1
# Out:
#                       MonthlyCharges
# Contract       Churn
# Month-to-month No          61.462635
#                Yes         73.019396
# One year       No          62.508148
#                Yes         85.050904
# Two year       No          60.012477
#                Yes         86.777083

# %%
group_2 = ((df.groupby(["Contract"])["Churn"].value_counts(normalize=True))*100).round(2).astype(str) + '%'
group_2
# Out:
# Contract        Churn
# Month-to-month  No       57.29%
#                 Yes      42.71%
# One year        No       88.73%
#                 Yes      11.27%
# Two year        No       97.17%
#                 Yes       2.83%
# Name: proportion, dtype: object

# %%
group_final = pd.merge(group_1, group_2, on =['Contract', 'Churn'] , how='left')
group_final.rename(columns = {"proportion" : "percentage Churn"}, inplace=True)
group_final
# Out:
#                       MonthlyCharges percentage Churn
# Contract       Churn
# Month-to-month No          61.462635           57.29%
#                Yes         73.019396           42.71%
# One year       No          62.508148           88.73%
#                Yes         85.050904           11.27%
# Two year       No          60.012477           97.17%
#                Yes         86.777083            2.83%

# %% [markdown]
# ## Soal 3:
# Buat pivot table untuk menganalisis hubungan antara jenis kontrak dan metode pembayaran
# terhadap rata-rata tagihan bulanan.

# %%
tabel_pivot = pd.pivot_table(df, values='MonthlyCharges', index='Contract', columns='PaymentMethod', aggfunc='count')
tabel_pivot
# Out:
# PaymentMethod   Bank transfer (automatic)  Credit card (automatic)  \
# Contract
# Month-to-month                        589                      543
# One year                              391                      398
# Two year                              564                      581
#
# PaymentMethod   Electronic check  Mailed check
# Contract
# Month-to-month              1850           893
# One year                     347           337
# Two year                     168           382

# %% [markdown]
# ## Soal 4
# Buat crosstab untuk mengevaluasi hubungan antara churn dan metode pembayaran, serta
# menghitung persentase churn untuk setiap metode pembayaran.

# %%
# crostab hubungan antara paymentmethod dengan churn
crosstab = pd.crosstab(df['PaymentMethod'], df['Churn'])
crosstab
# Out:
# Churn                        No   Yes
# PaymentMethod
# Bank transfer (automatic)  1286   258
# Credit card (automatic)    1290   232
# Electronic check           1294  1071
# Mailed check               1304   308

# %%
# crosstab persentase churn pada setiap metode pembayaran dalam persen
crosstab_persen = pd.crosstab(df['PaymentMethod'], df['Churn'], margins= True,normalize = 'index')
crosstab_persen
# Out:
# Churn                            No       Yes
# PaymentMethod
# Bank transfer (automatic)  0.832902  0.167098
# Credit card (automatic)    0.847569  0.152431
# Electronic check           0.547146  0.452854
# Mailed check               0.808933  0.191067
# All                        0.734630  0.265370

# %% [markdown]
# # Soal 5
# Buat aggregation untuk mengevaluasi total churn dengan senior citizen yes dan dependents
# lebih dari 0, serta menghitung total churn dari gender dengan kontrak year.

# %%
df['Churn'] = df['Churn'].map({'Yes': 1, 'No': 0})

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
#  16  PaperlessBilling  7043 non-null   object
#  17  PaymentMethod     7043 non-null   object
#  18  MonthlyCharges    7043 non-null   float64
#  19  TotalCharges      7043 non-null   object
#  20  Churn             7043 non-null   int64
# dtypes: float64(1), int64(3), object(17)
# memory usage: 1.1+ MB

# %%
x = df[(df["SeniorCitizen"] > 0) & (df["Dependents"] == "Yes") & (df["Churn"] >0)]
x
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 630   5099-BAILX    Male              1     Yes        Yes      43
# 638   4913-EHYUI    Male              1     Yes        Yes      56
# 1029  4184-TJFAN  Female              1     Yes        Yes       3
# 1670  5047-LHVLY    Male              1      No        Yes       1
# 2282  1587-FKLZB    Male              1     Yes        Yes      66
# 2415  9898-KZQDZ  Female              1     Yes        Yes      40
# 2483  7641-EUYET    Male              1     Yes        Yes      46
# 2578  0354-WYROK  Female              1     Yes        Yes      31
# 2690  2397-BRLOM    Male              1     Yes        Yes       8
# 2888  7409-KIUTL  Female              1      No        Yes       1
# 2890  1732-VHUBQ  Female              1     Yes        Yes      47
# 2900  0679-IDSTG  Female              1     Yes        Yes       1
# 3600  8623-TMRBY    Male              1     Yes        Yes      51
# 3615  6900-PXRMS    Male              1     Yes        Yes      26
# 3779  8631-NBHFZ    Male              1     Yes        Yes      66
# 3875  2403-BCASL    Male              1     Yes        Yes      41
# 4513  8580-QVLOC  Female              1     Yes        Yes      72
# 4928  2718-GAXQD  Female              1     Yes        Yes       4
# 5183  8988-ECPJR  Female              1     Yes        Yes      34
# 5702  5287-QWLKY    Male              1     Yes        Yes      71
# 6235  5180-UCIIQ    Male              1     Yes        Yes      22
# 6346  9661-MHUMO    Male              1     Yes        Yes       1
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  \
# 630           Yes               Yes     Fiber optic             No
# 638           Yes               Yes     Fiber optic            Yes
# 1029          Yes                No     Fiber optic            Yes
# 1670          Yes                No             DSL             No
# 2282          Yes               Yes     Fiber optic             No
# 2415          Yes               Yes     Fiber optic             No
# 2483          Yes               Yes     Fiber optic            Yes
# 2578          Yes                No     Fiber optic             No
# 2690          Yes                No     Fiber optic             No
# 2888          Yes                No     Fiber optic             No
# 2890          Yes                No     Fiber optic             No
# 2900          Yes                No     Fiber optic             No
# 3600          Yes               Yes     Fiber optic             No
# 3615          Yes               Yes     Fiber optic             No
# 3779          Yes               Yes             DSL            Yes
# 3875          Yes               Yes     Fiber optic             No
# 4513          Yes               Yes             DSL            Yes
# 4928          Yes                No             DSL             No
# 5183          Yes               Yes     Fiber optic             No
# 5702          Yes               Yes     Fiber optic            Yes
# 6235           No  No phone service             DSL            Yes
# 6346          Yes                No             DSL             No
#
#      OnlineBackup DeviceProtection TechSupport StreamingTV StreamingMovies  \
# 630           Yes              Yes         Yes         Yes             Yes
# 638            No              Yes          No         Yes             Yes
# 1029           No               No         Yes         Yes              No
# 1670           No              Yes          No          No              No
# 2282           No              Yes          No         Yes             Yes
# 2415           No               No          No         Yes             Yes
# 2483          Yes              Yes          No         Yes              No
# 2578           No              Yes         Yes         Yes             Yes
# 2690           No               No          No         Yes              No
# 2888           No               No          No          No              No
# 2890           No               No          No          No              No
# 2900           No               No          No          No              No
# 3600          Yes              Yes          No          No              No
# 3615          Yes              Yes          No         Yes             Yes
# 3779          Yes              Yes         Yes         Yes              No
# 3875          Yes              Yes         Yes         Yes             Yes
# 4513          Yes              Yes         Yes         Yes             Yes
# 4928           No               No          No          No              No
# 5183          Yes               No          No          No              No
# 5702          Yes               No          No         Yes             Yes
# 6235           No               No          No          No             Yes
# 6346           No               No         Yes          No              No
#
#             Contract PaperlessBilling              PaymentMethod  \
# 630   Month-to-month              Yes  Bank transfer (automatic)
# 638         One year              Yes  Bank transfer (automatic)
# 1029  Month-to-month              Yes               Mailed check
# 1670  Month-to-month              Yes               Mailed check
# 2282  Month-to-month              Yes    Credit card (automatic)
# 2415  Month-to-month              Yes    Credit card (automatic)
# 2483  Month-to-month              Yes           Electronic check
# 2578  Month-to-month              Yes           Electronic check
# 2690  Month-to-month              Yes    Credit card (automatic)
# 2888  Month-to-month              Yes           Electronic check
# 2890  Month-to-month               No  Bank transfer (automatic)
# 2900  Month-to-month              Yes           Electronic check
# 3600  Month-to-month              Yes           Electronic check
# 3615  Month-to-month               No           Electronic check
# 3779        Two year               No    Credit card (automatic)
# 3875        One year              Yes           Electronic check
# 4513        Two year               No    Credit card (automatic)
# 4928  Month-to-month               No           Electronic check
# 5183  Month-to-month              Yes               Mailed check
# 5702  Month-to-month              Yes    Credit card (automatic)
# 6235  Month-to-month               No               Mailed check
# 6346  Month-to-month              Yes    Credit card (automatic)
#
#       MonthlyCharges TotalCharges  Churn
# 630           110.75       4687.9      1
# 638           104.55      5794.65      1
# 1029           88.30       273.75      1
# 1670           50.15        50.15      1
# 2282           99.50      6822.15      1
# 2415           94.55      3640.45      1
# 2483          100.70       4541.2      1
# 2578           98.90       2911.3      1
# 2690           80.45       583.45      1
# 2888           71.00           71      1
# 2890           70.55      3309.25      1
# 2900           69.25        69.25      1
# 3600           84.20      4146.05      1
# 3615          105.75      2710.25      1
# 3779           79.40       5154.6      1
# 3875          111.95       4534.9      1
# 4513           92.45      6440.25      1
# 4928           46.00        181.6      1
# 5183           79.60       2718.3      1
# 5702          105.10       7548.1      1
# 6235           40.05        880.2      1
# 6346           49.25        49.25      1

# %%
#mengevaluasi total churn terhadap seniorcitizen yes dan dependants yes
agg = x.groupby(["SeniorCitizen","Dependents"]).agg({"Churn" : "sum"})
agg
# Out:
#                           Churn
# SeniorCitizen Dependents
# 1             Yes            22

# %%
#menghitung total churn terhadap gender dengan kontrak year
y = df[(df["Contract"] != "Month-to-month") & (df["Churn"] >0)]
y
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 104   3192-NQECA    Male              0     Yes         No      68
# 173   0691-JVSYA  Female              0     Yes         No      53
# 268   6323-AYBRX    Male              0      No         No      59
# 317   2321-OMBXY  Female              0     Yes        Yes      38
# 320   5020-ZSTTY  Female              1      No         No      54
# ...          ...     ...            ...     ...        ...     ...
# 6918  8267-ZNYVZ  Female              0     Yes         No      33
# 6945  6797-LNAQX    Male              0     Yes        Yes      70
# 6972  6664-FPDAC  Female              1      No         No      56
# 6996  4174-LPGTI  Female              0     Yes        Yes      41
# 7021  1699-HPSBG    Male              0      No         No      12
#
#      PhoneService MultipleLines InternetService       OnlineSecurity  \
# 104           Yes           Yes     Fiber optic                   No
# 173           Yes            No     Fiber optic                   No
# 268           Yes            No              No  No internet service
# 317           Yes            No             DSL                  Yes
# 320           Yes           Yes             DSL                  Yes
# ...           ...           ...             ...                  ...
# 6918          Yes            No     Fiber optic                  Yes
# 6945          Yes           Yes     Fiber optic                   No
# 6972          Yes           Yes     Fiber optic                   No
# 6996          Yes            No             DSL                   No
# 7021          Yes            No             DSL                   No
#
#              OnlineBackup     DeviceProtection          TechSupport  \
# 104                   Yes                  Yes                  Yes
# 173                    No                  Yes                   No
# 268   No internet service  No internet service  No internet service
# 317                   Yes                   No                  Yes
# 320                   Yes                   No                  Yes
# ...                   ...                  ...                  ...
# 6918                   No                  Yes                  Yes
# 6945                  Yes                   No                   No
# 6972                  Yes                  Yes                  Yes
# 6996                  Yes                   No                  Yes
# 7021                   No                   No                  Yes
#
#               StreamingTV      StreamingMovies  Contract PaperlessBilling  \
# 104                   Yes                  Yes  Two year              Yes
# 173                   Yes                  Yes  One year              Yes
# 268   No internet service  No internet service  Two year               No
# 317                   Yes                  Yes  One year               No
# 320                   Yes                  Yes  One year               No
# ...                   ...                  ...       ...              ...
# 6918                  Yes                  Yes  One year              Yes
# 6945                  Yes                  Yes  Two year               No
# 6972                  Yes                  Yes  One year              Yes
# 6996                   No                  Yes  One year              Yes
# 7021                  Yes                   No  One year              Yes
#
#                   PaymentMethod  MonthlyCharges TotalCharges  Churn
# 104   Bank transfer (automatic)          110.00      7611.85      1
# 173   Bank transfer (automatic)           94.85       5000.2      1
# 268                Mailed check           19.35       1099.6      1
# 317     Credit card (automatic)           80.30      3058.65      1
# 320   Bank transfer (automatic)           82.45       4350.1      1
# ...                         ...             ...          ...    ...
# 6918           Electronic check          103.75      3361.05      1
# 6945  Bank transfer (automatic)           98.30       6859.5      1
# 6972           Electronic check          111.95       6418.9      1
# 6996  Bank transfer (automatic)           66.50       2728.6      1
# 7021           Electronic check           59.80        727.8      1
#
# [214 rows x 21 columns]

# %%
#mengevaluasi total churn terhadap seniorcitizen yes dan dependants yes
agg2 = y.groupby(["gender","Contract"]).agg({"Churn" : "sum"})
agg2
# Out:
#                  Churn
# gender Contract
# Female One year     75
#        Two year     22
# Male   One year     91
#        Two year     26
